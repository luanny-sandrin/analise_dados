# %%
import pandas as pd
# !pip install openpyxl
import openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 23.3.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
path = r"H:\Python\3°etapa\Atividade 4\CD2022_Populacao_2010_Compatibilizada_20231222.xlsx"

# %%
bruto = pd.read_excel(path, header=2)

# %%
bruto
# Out:
#       Unnamed: 0                                                 UF  COD. UF  \
# 0            NaN                                                 RO     11.0
# 1            NaN                                                 RO     11.0
# 2            NaN                                                 RO     11.0
# 3            NaN                                                 RO     11.0
# 4            NaN                                                 RO     11.0
# ...          ...                                                ...      ...
# 5569         NaN                                                 DF     53.0
# 5570         NaN                                                NaN      NaN
# 5571         NaN  Nota: Para o cálculo das taxas de crescimento ...      NaN
# 5572         NaN                                                NaN      NaN
# 5573         NaN  Fonte: IBGE. Diretoria de Pesquisas - DPE -  C...      NaN
#
# ...

# %%
trabalhado = bruto.iloc[0:5570, 1:]

# %%
trabalhado
# Out:
#       UF  COD. UF  COD. MUNIC      NOME DO MUNICÍPIO  \
# 0     RO     11.0        15.0  Alta Floresta D'Oeste
# 1     RO     11.0        23.0              Ariquemes
# 2     RO     11.0        31.0                 Cabixi
# 3     RO     11.0        49.0                 Cacoal
# 4     RO     11.0        56.0             Cerejeiras
# ...   ..      ...         ...                    ...
# 5565  GO     52.0     22005.0             Vianópolis
# 5566  GO     52.0     22054.0         Vicentinópolis
# 5567  GO     52.0     22203.0               Vila Boa
# 5568  GO     52.0     22302.0          Vila Propício
# 5569  DF     53.0       108.0               Brasília
#
#       População Município 2010\n(Sinopse)  \
# 0                                 24392.0
# 1                                 90353.0
# 2                                  6313.0
# 3                                 78574.0
# 4                                 17029.0
# ...                                   ...
# ...

# %%
trabalhado.columns
# Out:
# Index(['UF', 'COD. UF', 'COD. MUNIC', 'NOME DO MUNICÍPIO',
#        'População Município 2010\n(Sinopse)',
#        'População 2010 (Alterações de Limites até 2022)1',
#        'População Censo 2022'],
#       dtype='str')

# %%
trabalhado["diferença"] = trabalhado['População Censo 2022'] - trabalhado['População Município 2010\n(Sinopse)']

# %%
trabalhado
# Out:
#       UF  COD. UF  COD. MUNIC      NOME DO MUNICÍPIO  \
# 0     RO     11.0        15.0  Alta Floresta D'Oeste
# 1     RO     11.0        23.0              Ariquemes
# 2     RO     11.0        31.0                 Cabixi
# 3     RO     11.0        49.0                 Cacoal
# 4     RO     11.0        56.0             Cerejeiras
# ...   ..      ...         ...                    ...
# 5565  GO     52.0     22005.0             Vianópolis
# 5566  GO     52.0     22054.0         Vicentinópolis
# 5567  GO     52.0     22203.0               Vila Boa
# 5568  GO     52.0     22302.0          Vila Propício
# 5569  DF     53.0       108.0               Brasília
#
#       População Município 2010\n(Sinopse)  \
# 0                                 24392.0
# 1                                 90353.0
# 2                                  6313.0
# 3                                 78574.0
# 4                                 17029.0
# ...                                   ...
# ...

# %%
trabalhado.to_csv(r"H:\Python\3°etapa\Atividade 4\Trabalhado.csv", sep=";")

# %%
trabalhado.columns
# Out:
# Index(['UF', 'COD. UF', 'COD. MUNIC', 'NOME DO MUNICÍPIO',
#        'População Município 2010\n(Sinopse)',
#        'População 2010 (Alterações de Limites até 2022)1',
#        'População Censo 2022', 'diferença'],
#       dtype='str')

# %%
estado = trabalhado.groupby("UF")[['População 2010 (Alterações de Limites até 2022)1',
       'População Censo 2022', 'diferença']].sum().reset_index()

# %%
estado
# Out:
#     UF  População 2010 (Alterações de Limites até 2022)1  \
# 0   AC                                          733559.0
# 1   AL                                         3120887.0
# 2   AM                                         3483985.0
# 3   AP                                          669526.0
# 4   BA                                        14017071.0
# 5   CE                                         8451644.0
# 6   DF                                         2572159.0
# 7   ES                                         3514952.0
# 8   GO                                         6001789.0
# 9   MA                                         6574789.0
# 10  MG                                        19597330.0
# 11  MS                                         2449024.0
# 12  MT                                         3035122.0
# 13  PA                                         7581051.0
# 14  PB                                         3766528.0
# ...

# %%
estado.to_csv(r"H:\Python\3°etapa\Atividade 4\Estado.csv", sep=";")
